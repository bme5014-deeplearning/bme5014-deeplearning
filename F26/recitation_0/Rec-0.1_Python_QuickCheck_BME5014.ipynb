# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/bme5014-deeplearning/bme5014-deeplearning/blob/main/F26/recitation_0/Rec-0.1_Python_QuickCheck_BME5014.ipynb)

# %% [markdown]
# # Python Quick Check: Interactive Skills Practice (BME5014)
#
# This notebook tests and reinforces the skills from the **Recitation 0.1 Python Fundamentals** notebook, using small biomedical-flavored examples.
#
# **Instructions:**
# - Read each task carefully.
# - Fill in the `# TODO` sections.
# - Run the cell to check your work.
# - A cell that prints **All tests passed!** (or similar) means you got it right.
#
# Try not to scroll ahead, treat each section like a mini quiz.

# %% [markdown]
# ## 1. Variables and Basic Types
#
# **Goal:** Create variables of different basic types, using values you'd typically see on a patient monitor.
#
# **Task:**
# - Create:
#   - `heart_rate` with any integer value (beats per minute).
#   - `body_temp_c` with any floating point value (degrees Celsius).
#   - `patient_id` with any short string.
#   - `is_critical` with either `True` or `False`.
# - Then run the cell to check your work.

# %%
# TODO: Define the variables with appropriate types
heart_rate = ...
body_temp_c = ...
patient_id = ...
is_critical = ...

# --- Do not modify below this line ---
assert isinstance(heart_rate, int), "heart_rate must be an int"
assert isinstance(body_temp_c, float), "body_temp_c must be a float"
assert isinstance(patient_id, str), "patient_id must be a string"
assert isinstance(is_critical, bool), "is_critical must be a bool"
print("All tests passed for basic types!")

# %% [markdown]
# ## 2. Strings and f-Strings
#
# **Goal:** Practice building readable strings with f-strings.
#
# **Task:**
# - Use an f-string to set `message` to the string:
#
#   `"Patient Ada, age 30 years old."`
#
# - Do it by using the variables `patient_name` and `age` instead of hard coding the text.

# %%
patient_name = "John"
age = 30

# TODO: Use an f-string and the variables above
message = ...  # e.g., f"..."

# --- Do not modify below this line ---
assert message == "Patient Ada, age 30 years old.", "Check your f-string formatting."
print("f-string looks good!")

# %% [markdown]
# ## 3. Lists, Dictionaries, and Sets
#
# **Goal:** Work with basic data structures using a small set of heart-rate readings.
#
# **Task:**
# - Create a list `heart_rates` containing the readings `60, 62, 64, 66, 68` (in that order).
# - Create a dictionary `hr_doubled` that maps each reading in `heart_rates` to twice its value.
# - Create a set `high_readings` containing only the readings above `65`.

# %%
# TODO: Create heart_rates, hr_doubled, and high_readings as described
heart_rates = ...     # a list: [60, 62, 64, 66, 68]
hr_doubled = ...      # a dict mapping each reading to twice its value
high_readings = ...   # a set of readings above 65

# --- Do not modify below this line ---
assert heart_rates == [60, 62, 64, 66, 68], "heart_rates should be [60, 62, 64, 66, 68]"
assert isinstance(hr_doubled, dict), "hr_doubled must be a dict"
assert hr_doubled.get(64) == 128, "hr_doubled[64] should be 128"
assert isinstance(high_readings, set), "high_readings must be a set"
assert high_readings == {66, 68}, "high_readings should be {66, 68}"
print("Data structures look good!")

# %% [markdown]
# ## 4. Comprehensions
#
# **Goal:** Use list and dict comprehensions on a small set of temperature readings.
#
# **Task:**
# - Using the list `temps_f` below (patient temperatures in Fahrenheit), create:
#   - `fevers_f`: a list of only the temperatures **above** `100.4` (the standard fever threshold).
#   - `temp_to_c`: a dictionary mapping each Fahrenheit temperature to its Celsius equivalent,
#     computed as `(f - 32) * 5 / 9` and rounded to 1 decimal place with `round(..., 1)`.

# %%
temps_f = [97.0, 98.6, 100.4, 101.5, 103.1]

# TODO: Use comprehensions
fevers_f = ...    # [t for t in temps_f if ...]
temp_to_c = ...   # {t: round((t - 32) * 5 / 9, 1) for t in temps_f}

# --- Do not modify below this line ---
assert fevers_f == [101.5, 103.1], "fevers_f should be [101.5, 103.1]"
assert isinstance(temp_to_c, dict), "temp_to_c must be a dict"
assert temp_to_c.get(98.6) == 37.0, "98.6F should map to 37.0C"
assert temp_to_c.get(100.4) == 38.0, "100.4F should map to 38.0C"
print("Nice use of comprehensions!")

# %% [markdown]
# ## 5. Conditionals and Loops
#
# **Goal:** Combine `if` statements and loops to flag abnormal heart-rate readings.
#
# **Task:**
# - Write a loop that goes through `heart_rates`.
# - Build a list `labels` where each element is:
#   - `'normal'` if the reading is between `60` and `100` bpm **inclusive**
#   - `'abnormal'` otherwise
#
# *Hint:* Use an `if`/`else` inside the loop.

# %%
heart_rates = [55, 72, 100, 130, 58]

# TODO: Build labels using a loop and conditionals
labels = []
for hr in heart_rates:
    ...  # decide whether to append 'normal' or 'abnormal'

# --- Do not modify below this line ---
assert labels == ["abnormal", "normal", "normal", "abnormal", "abnormal"], "Check your loop logic."
print("Loop and conditionals are correct!")

# %% [markdown]
# ## 6. Functions
#
# **Goal:** Define and use a simple function.
#
# **Task:**
# - Write a function `double_if_even(n)` that:
#   - Returns `n * 2` if `n` is even.
#   - Returns `n` unchanged if `n` is odd.
#
# (You'll use this exact even/odd pattern constantly, e.g. when only certain channels of a signal need scaling.)

# %%
# TODO: Define the function
def double_if_even(n):
    ...

# --- Do not modify below this line ---
assert double_if_even(4) == 8, "4 should become 8"
assert double_if_even(5) == 5, "5 should stay 5"
print("Function behavior is correct!")

# %% [markdown]
# ## 7. Functions with Type Hints (Optional)
#
# **Goal:** Add simple type hints.
#
# **Task:**
# - Add type hints to `sum_readings` so that:
#   - The parameter `values` is a list of integers.
#   - The function returns an integer.

# %%
# TODO: Add type hints to the function signature
def sum_readings(values):
    total = 0
    for v in values:
        total += v
    return total

# --- Do not modify below this line ---
import inspect
sig = inspect.signature(sum_readings)
params = sig.parameters
has_annotation = params['values'].annotation is not inspect._empty
has_return = sig.return_annotation is not inspect._empty

assert has_annotation and has_return, "Please add type hints to the function signature."
assert sum_readings([1, 2, 3]) == 6, "sum_readings([1, 2, 3]) should be 6"
print("Type hints and function both look good!")

# %% [markdown]
# ## 8. Mutability
#
# **Goal:** See how lists can be modified inside a function.
#
# **Task:**
# - Complete the function `log_reading(readings, x)` so that:
#   - If `x` is positive, it appends `x` to the list `readings` (a negative value represents a bad sensor reading, which we discard).
#   - It returns the list in either case.

# %%
# TODO: Complete the function
def log_reading(readings, x):
    ...

vitals_log = [1, 2]
result = log_reading(vitals_log, 3)

# --- Do not modify below this line ---
assert vitals_log == [1, 2, 3], "vitals_log should be modified to [1, 2, 3]"
assert result is vitals_log, "Function should return the same list object"
print("Mutability behavior is correct!")

# %% [markdown]
# ## 9. Classes
#
# **Goal:** Define a simple class with an instance method.
#
# **Task:**
# - Create a class `DoseCounter` that:
#   - Has an attribute `value` starting at 0 (number of doses administered).
#   - Has a method `administer()` that increases `value` by 1.
#   - Has a method `reset()` that sets `value` back to 0.

# %%
# TODO: Define the DoseCounter class
class DoseCounter:
    ...

# --- Do not modify below this line ---
c = DoseCounter()
assert hasattr(c, 'value'), "DoseCounter should have a 'value' attribute"
start = c.value
c.administer()
assert c.value == start + 1, "administer() should increase value by 1"
c.reset()
assert c.value == 0, "reset() should set value back to 0"
print("Class definition looks good!")

# %% [markdown]
# ## 10. Exceptions
#
# **Goal:** Use try/except to handle errors.
#
# **Task:**
# - Complete `dose_per_kg(total_mg, weight_kg)` so that:
#   - It returns `total_mg / weight_kg` normally.
#   - If `weight_kg` is zero (e.g. a missing/invalid weight), it returns `None` instead of raising an error.

# %%
# TODO: Implement dose_per_kg using try/except
def dose_per_kg(total_mg, weight_kg):
    ...

# --- Do not modify below this line ---
assert dose_per_kg(10, 2) == 5, "10mg / 2kg should be 5"
assert dose_per_kg(5, 0) is None, "Division by zero weight should return None"
print("Exception handling works!")

# %% [markdown]
# ## 11. (Optional) Paths with pathlib
#
# **Goal:** Practice using `pathlib.Path`.
#
# **Task:**
# - Use `Path` to create a path `output_dir` named `'patient_reports'`.
# - Use `/` to join it with `'patient_001_report.txt'` and store it in `output_file`.
# - We will not actually write files here, this just checks that you built the paths correctly.

# %%
from pathlib import Path

# TODO: Build paths using Path
output_dir = ...            # e.g., Path("patient_reports")
output_file = ...           # e.g., output_dir / "patient_001_report.txt"

# --- Do not modify below this line ---
assert isinstance(output_dir, Path), "output_dir should be a Path object"
assert output_file.name == "patient_001_report.txt", "Filename should be patient_001_report.txt"
assert output_file.parent == output_dir, "Parent of output_file should be output_dir"
print("pathlib paths look correct!")

# %% [markdown]
# ## 12. NumPy and Matrix Basics
#
# We will now go through some NumPy and matrix basics. These will be used heavily in this class — whether you're working with 1D physiological signals or 2D/3D medical images. If this part feels simple, you are in good shape for BME5014. If it feels new or challenging, that does not mean you cannot take the class, just that you should plan to put extra effort into ramping up.

# %% [markdown]
# ### Creating Arrays and Basic Indexing
#
# **Goal:** Learn how to create NumPy arrays and access elements.
#
# **Task:**
# - Create a 1D NumPy array called `hr` containing five consecutive heart-rate readings: `72, 74, 76, 78, 80`.
# - Set a variable `third` equal to the third element in the array.
# - Set a variable `last` equal to the last element in the array.

# %%
import numpy as np

# TODO: Create hr, third, and last
# Your code here



# --- Do not modify below this line ---
assert isinstance(hr, np.ndarray), "hr should be a NumPy array"
assert hr.tolist() == [72, 74, 76, 78, 80], "hr should contain [72, 74, 76, 78, 80]"
assert third == 76, "third should be the value at index 2"
assert last == 80, "last should be the final element of hr"

print("Looks good!")

# %% [markdown]
# ### Matrix Shape and Reshaping
#
# **Goal:** Understand shapes and reshaping in NumPy, using a tiny image patch as an example.
#
# **Task:**
# - Create an array `patch` containing values 0 to 8 (think: raw pixel intensities from a scan).
# - Reshape it into a 3x3 matrix.
# - Store its shape in a variable `shape_patch`.

# %%
import numpy as np

# TODO: Define patch and shape_patch
# Your code here



# --- Do not modify below this line ---
assert patch.shape == (3, 3), "patch should be reshaped into a 3x3 matrix"
assert patch[1, 1] == 4, "Center value of patch should be 4"
assert shape_patch == (3, 3), "shape_patch should store (3, 3)"

print("Looks good!")

# %% [markdown]
# ### Matrix Slicing
#
# **Goal:** Practice slicing from matrices.
#
# **Task:**
# - Create the 3x3 matrix with values 1 through 9 in order, store it as `M` (another small image patch).
# - Extract the first row into `row1`.
# - Extract the first column into `col1`.
# - Extract the 2x2 top left block into `block`.

# %%
import numpy as np

# TODO: Define M, row1, col1, and block
# Your code here



# --- Do not modify below this line ---
assert M.shape == (3, 3), "M should be 3x3"
assert row1.tolist() == [1, 2, 3], "row1 should be the first row"
assert col1.tolist() == [1, 4, 7], "col1 should be the first column"
assert block.tolist() == [[1, 2], [4, 5]], "block should be the 2x2 top left corner"

print("Looks good!")

# %% [markdown]
# ### Elementwise Operations
#
# **Goal:** Learn how broadcasting and elementwise operations work in NumPy.
#
# **Task:**
# - Create array `x = [1, 2, 3]`.
# - Create array `y = [10, 20, 30]`.
# - Compute:
#   - `sum_xy = x + y`
#   - `square_x = x ** 2`

# %%
import numpy as np

# TODO: Define x, y, sum_xy, and square_x
# Your code here



# --- Do not modify below this line ---
assert sum_xy.tolist() == [11, 22, 33], "sum of x and y should be [11, 22, 33]"
assert square_x.tolist() == [1, 4, 9], "square_x should square each element"

print("Looks good!")

# %% [markdown]
# ### Matrix Multiplication vs Elementwise Multiplication
#
# **Goal:** Understand the difference between `*` (elementwise / Hadamard — e.g. applying a segmentation mask to an image) and `@` (matrix multiplication — e.g. the computation inside a neural network layer).
#
# **Task:**
#
# Given:
#
# ```
# A = [[1, 2],
#      [3, 4]]
# B = [[2, 0],
#      [1, 2]]
# ```
#
# - Compute the elementwise product as `hadamard`.
# - Compute the matrix product as `matmul`.

# %%
import numpy as np

# TODO: Define A, B, hadamard, and matmul
# Your code here



# --- Do not modify below this line ---
assert hadamard.tolist() == [[2, 0], [3, 8]], "Hadamard product incorrect"
assert matmul.tolist() == [[4, 4], [10, 8]], "Matrix multiplication incorrect"

print("Looks good!")

# %% [markdown]
# ## Self Reflection
#
# If this was all a breeze for you, you are ready to start your journey into Deep Learning for biomedical applications. If you really struggled with this, do not be discouraged, just know you will likely need to put in some extra effort to excel in this class. Office hours exist specifically to help with this, so don't hesitate to use them.
